# %%
# !pip install python-twitter
# Out:
# Requirement already satisfied: python-twitter in /usr/local/lib/python3.6/dist-packages (3.5)
# Requirement already satisfied: future in /usr/local/lib/python3.6/dist-packages (from python-twitter) (0.16.0)
# Requirement already satisfied: requests-oauthlib in /usr/local/lib/python3.6/dist-packages (from python-twitter) (1.3.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.6/dist-packages (from python-twitter) (2.23.0)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.6/dist-packages (from requests-oauthlib->python-twitter) (3.1.0)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.6/dist-packages (from requests->python-twitter) (3.0.4)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.6/dist-packages (from requests->python-twitter) (2.9)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.6/dist-packages (from requests->python-twitter) (1.24.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.6/dist-packages (from requests->python-twitter) (2020.4.5.1)

# %%
import twitter

# %%
# api = twitter.Api(consumer_key='58wlGpzEOwum6nghvA8tj6nz6',
#                   consumer_secret='b04KqyzRyquIiYGwqv9B12hRqjEj9tvOp53DtoFZJtetaZ7cZE',
#                   access_token_key='1243275961824612358-65qxIlXTEhjw0jlbBaK4I0olH9nRP9',
#                   access_token_secret='wYdkYaNCakb7sX5PnHjF1u0oJc7Y73iijqbJ4VeB4yyEd')

api = twitter.Api(access_token_key = "1241834718041079813-ZVao5dbS9ZruOKRDS3F26QNCsNcJeA",
access_token_secret = "HLQJ2FVD2cFvHGsb4QsI0zFB2Osqn6fnTjvRZPd4W4PKp",
consumer_key = "jgEpawjd9vW6Rldr9ipAMiSpI",
consumer_secret = "BOxMYACTAsq8pPc6RtuSaz6MxjtHdxQrJfPD7XenUZldQFbEBD")
api

# %%
print(api.VerifyCredentials())
# Out:
# {"created_at": "Sun Mar 22 21:11:05 +0000 2020", "default_profile": true, "default_profile_image": true, "id": 1241834718041079813, "id_str": "1241834718041079813", "name": "Gaurav", "profile_background_color": "F5F8FA", "profile_image_url": "http://abs.twimg.com/sticky/default_profile_images/default_profile_normal.png", "profile_image_url_https": "https://abs.twimg.com/sticky/default_profile_images/default_profile_normal.png", "profile_link_color": "1DA1F2", "profile_sidebar_border_color": "C0DEED", "profile_sidebar_fill_color": "DDEEF6", "profile_text_color": "333333", "profile_use_background_image": true, "screen_name": "Gaurav23173827", "status": {"created_at": "Mon Apr 13 17:30:49 +0000 2020", "id": 1249751909331861511, "id_str": "1249751909331861511", "lang": "en", "retweet_count": 538, "retweeted": true, "retweeted_status": {"created_at": "Wed Jan 22 00:23:57 +0000 2020", "favorite_count": 566, "id": 1219777687138422785, "id_str": "1219777687138422785", "lang": "en", "retweet_count": 538, "retweeted": true, "source": "<a href=\"http://twitter.com/download/iphone\" rel=\"nofollow\">Twitter for iPhone</a>", "text": "\ud83c\udde8\ud83c\uddf3 #ChinaPneumonia\n\u2014 The CDC has confirmed the FIRST #US case of Wuhan #coronavirus after a traveler was diagnosed\u2026 https://t.co/YLplWNg6WO", "truncated": true}, "source": "<a href=\"https://mobile.twitter.com\" rel=\"nofollow\">Twitter Web App</a>", "text": "RT @Dystopia992: \ud83c\udde8\ud83c\uddf3 #ChinaPneumonia\n\u2014 The CDC has confirmed the FIRST #US case of Wuhan #coronavirus after a traveler was diagnosed in Seat\u2026"}, "statuses_count": 1}

# %%
search = api.GetSearch("https://www.nytimes.com/2020/05/31/us/george-floyd-protests-live-updates.html")

# %%
len(search)
# Out:
# 15

# %%
search
# Out:
# [Status(ID=1267266912704233473, ScreenName=FloLake, Created=Mon Jun 01 01:29:11 +0000 2020, Text='George Floyd Protests Live Updates: Demonstrations Resume as Mayors Call for ‘Peace, Not Patience’ https://t.co/F4U0zkIYoD'),
#  Status(ID=1267262365797662720, ScreenName=SteveOnFront242, Created=Mon Jun 01 01:11:07 +0000 2020, Text='Live George Floyd Protest Updates and Video https://t.co/7FdZ3BaMRV https://t.co/hqxRa09M39'),
#  Status(ID=1267256213378600966, ScreenName=tripled355, Created=Mon Jun 01 00:46:40 +0000 2020, Text='https://t.co/4ynu4qC21q https://t.co/xf22Hw8zMA'),
#  Status(ID=1267254250570051584, ScreenName=sk_saluja, Created=Mon Jun 01 00:38:52 +0000 2020, Text='USA LIVE GEORGE FLOYD PROTESTS UPDATES AND VIDEO\n https://t.co/7P0Eh6VGBd'),
#  Status(ID=1267251716417708032, ScreenName=aytsafety, Created=Mon Jun 01 00:28:48 +0000 2020, Text='Peace! George Floyd Protests Live Updates: Demonstrations Resume as Mayors Call for ‘Peace, Not Patience’ https://t.co/B4e8526kKQ'),
#  Status(ID=1267250659566354432, ScreenName=AuntyAlias, Created=Mon Jun 01 00:24:36 +0000 2020, Text='Update: One day after video showed them using stun guns on two black college students and then dragging them out of… https://t.co/dtajJOlFyl'),
#  Status(ID=1267250405878054912, ScreenName=NetNewsBuzz, Created=Mon Jun 01 00:23:35 +0000 2020, Text='RT @ghostdansing: George Floyd Protests Live Updates: Demonstrations Resume as Mayors Call for ‘Peace, Not Patience’ https://t.co/1T9sAIUoxL'),
#  Status(ID=1267249911961137159, ScreenName=ghostdansing, Created=Mon Jun 01 00:21:38 +0000 2020, Text='George Floyd Protests Live Updates: Demonstrations Resume as Mayors Call for ‘Peace, Not Patience’ https://t.co/1T9sAIUoxL'),
#  Status(ID=1267249547560050688, ScreenName=WorldMixx, Created=Mon Jun 01 00:20:11 +0000 2020, Text='"George Floyd Protests Live Updates: Demonstrations Resume as Mayors Call for ‘Peace, Not Patience’" by Unknown Aut… https://t.co/AzfSLX5k42')]

# %%
dir(search[1])
# Out:
# ['AsDict',
#  'AsJsonString',
#  'NewFromJsonDict',
#  '__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  '_json',
#  'contributors',
#  'coordinates',
#  'created_at',
#  'created_at_in_seconds',
#  'current_user_retweet',
#  'favorite_count',
#  'favorited',
#  'full_text',
#  'geo',
#  'hashtags',
#  'id',
#  'id_str',
#  'in_reply_to_screen_name',
#  'in_reply_to_status_id',
#  'in_reply_to_user_id',
#  'lang',
#  'location',
#  'media',
#  'param_defaults',
#  'place',
#  'possibly_sensitive',
#  'quoted_status',
#  'quoted_status_id',
#  'quoted_status_id_str',
#  'retweet_count',
#  'retweeted',
#  'retweeted_status',
#  'scopes',
#  'source',
#  'text',
#  'truncated',
#  'tweet_mode',
#  'urls',
#  'user',
#  'user_mentions',
#  'withheld_copyright',
#  'withheld_in_countries',
#  'withheld_scope']

# %%
search[0].retweet_count
# Out:
# 231

# %%
search[0].favourite_count
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-20-a88876b755f8> in <module>()
# ----> 1 search[0].favourite_count
#
# AttributeError: 'Status' object has no attribute 'favourite_count'

# %% [markdown]
# Tweepy

# %%
# !pip install tweepy
# Out:
# Requirement already satisfied: tweepy in /usr/local/lib/python3.6/dist-packages (3.6.0)
# Requirement already satisfied: requests>=2.11.1 in /usr/local/lib/python3.6/dist-packages (from tweepy) (2.21.0)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.6/dist-packages (from tweepy) (1.3.0)
# Requirement already satisfied: PySocks>=1.5.7 in /usr/local/lib/python3.6/dist-packages (from tweepy) (1.7.1)
# Requirement already satisfied: six>=1.10.0 in /usr/local/lib/python3.6/dist-packages (from tweepy) (1.12.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.6/dist-packages (from requests>=2.11.1->tweepy) (2019.11.28)
# Requirement already satisfied: urllib3<1.25,>=1.21.1 in /usr/local/lib/python3.6/dist-packages (from requests>=2.11.1->tweepy) (1.24.3)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in /usr/local/lib/python3.6/dist-packages (from requests>=2.11.1->tweepy) (3.0.4)
# Requirement already satisfied: idna<2.9,>=2.5 in /usr/local/lib/python3.6/dist-packages (from requests>=2.11.1->tweepy) (2.8)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.6/dist-packages (from requests-oauthlib>=0.7.0->tweepy) (3.1.0)

# %%
import tweepy

# %%
consumer_key='58wlGpzEOwum6nghvA8tj6nz6'
consumer_secret='b04KqyzRyquIiYGwqv9B12hRqjEj9tvOp53DtoFZJtetaZ7cZE'
access_token_key='1243275961824612358-65qxIlXTEhjw0jlbBaK4I0olH9nRP9'
access_token_secret='wYdkYaNCakb7sX5PnHjF1u0oJc7Y73iijqbJ4VeB4yyEd'

# %%
def get_api():
    auth=tweepy.OAuthHandler(consumer_key, consumer_secret)
    auth.set_access_token(access_token_key, access_token_secret)
    api = tweepy.API(auth, wait_on_rate_limit=True)
    return api

def get_tweet(url):
    tweet_id = url.split('/')[-1]
    api = get_api()
    tweet = api.get_status(tweet_id, tweet_mode="extended")
    return tweet

def get_twitter_url(user_name, status_id):
    return "https://twitter.com/" + str(user_name) + "/status/" + str(status_id)

# %%
def update_urls(tweet, api, urls):
    tweet_id = tweet.id
    user_name = tweet.user.screen_name
    max_id = None
    replies = tweepy.Cursor(api.search, q='to:{}'.format(user_name),
                                since_id=tweet_id, max_id=max_id, tweet_mode='extended').items()

    for reply in replies:
        if(reply.in_reply_to_status_id == tweet_id):
            urls.append(get_twitter_url(user_name, reply.id))
            try:
                for reply_to_reply in update_urls(reply, api, urls):
                    pass
            except Exception:
                pass
        max_id = reply.id
    return urls

# %%
url = 'https://twitter.com/nytimes/status/1244736178303139840'
api = get_api()
tweet = get_tweet(url)
# print(tweet.author)
# print(tweet.created_at)
# print(tweet.entities)
# print(tweet.favorite)
# print(tweet.favorite_count)
# print(tweet.favorited)
# print(tweet.id_str)
# print(tweet.in_reply_to_screen_name)
# print(tweet.in_reply_to_status_id_str)
# print(tweet.in_reply_to_user_id_str)
# print(tweet.is_quote_status)
# print(tweet.lang)
# print(tweet.parse)
# print(tweet.parse_list)
# print(tweet.retweet)
# print(tweet.retweet_count)
# print(tweet.retweeted)
# print(tweet.retweets)
# print(tweet.source)
# print(tweet.text)
# print(tweet.truncated)
# print(tweet.user)
# dir(tweet)
urls = [url]
urls = update_urls(tweet, api, urls)

# %%
urls
# Out:
# ['https://twitter.com/nytimes/status/1244736178303139840',
#  'https://twitter.com/nytimes/status/1244745134517956613',
#  'https://twitter.com/nytimes/status/1244744983996923904',
#  'https://twitter.com/nytimes/status/1244743588237500417',
#  'https://twitter.com/nytimes/status/1244742120683921408',
#  'https://twitter.com/nytimes/status/1244741168476213248',
#  'https://twitter.com/RockSergeant/status/1244742855970689026',
#  'https://twitter.com/Huron_Nation/status/1244743143641059328',
#  'https://twitter.com/RockSergeant/status/1244744101855100935',
#  'https://twitter.com/Huron_Nation/status/1244744352930226176',
#  'https://twitter.com/nytimes/status/1244739909535047683',
#  'https://twitter.com/nytimes/status/1244739195995897862',
#  'https://twitter.com/nytimes/status/1244738829484822529',
#  'https://twitter.com/nytimes/status/1244738696336867329',
#  'https://twitter.com/nytimes/status/1244737909586042886',
#  'https://twitter.com/nytimes/status/1244737195086188544',
#  'https://twitter.com/nytimes/status/1244736840810336268',
#  'https://twitter.com/donnynogood/status/1244736997664555008',
#  'https://twitter.com/atheistlover13/status/1244748289439870983',
#  'https://twitter.com/nytimes/status/1244736707339173891',
#  'https://twitter.com/nytimes/status/1244742681340850179',
#  'https://twitter.com/nytimes/status/1244740986498174979',
#  'https://twitter.com/nytimes/status/1244738595950407681',
#  'https://twitter.com/nytimes/status/1244737750621978625',
#  'https://twitter.com/nytimes/status/1244737372060860416',
#  'https://twitter.com/nytimes/status/1244737286060806145',
#  'https://twitter.com/nytimes/status/1244736697688039424',
#  'https://twitter.com/bacarty2/status/1244737084830576640',
#  'https://twitter.com/atheistlover13/status/1244737530194538497',
#  'https://twitter.com/bacarty2/status/1244739332713390080',
#  'https://twitter.com/guasacaca05/status/1244741159634776076',
#  'https://twitter.com/bacarty2/status/1244738102830043136',
#  'https://twitter.com/atheistlover13/status/1244738209587908608',
#  'https://twitter.com/nytimes/status/1244736425200734208']

# %%
comments = []
for url in urls:
    tweet = get_tweet(url)
    try:
        comments.append(tweet.retweeted_status.full_text)
    except AttributeError:  # Not a Retweet
        comments.append(tweet.full_text)

# %%
comments
# Out:
# ['There\'s growing fear of a public health catastrophe at New York\'s Rikers Island jail. Thousands of people are being held in conditions described as tense, crowded and unsanitary. "It’s like I’m doomed," one inmate said. "I feel like my life is in danger.”\nhttps://t.co/A7SnUTyqj9',
#  '@nytimes Masons want to get ride of America.. end of story',
#  '@nytimes ""I feel like my life is in danger.”"\n\nKind of like how your victims felt?',
#  '@nytimes We will soon see what/who will kill more people: coronavirus or criminals released from prisons.',
#  '@nytimes Honestly these are the last people to complain. \nSorry not sorry.',
#  '@nytimes But they already released the pedophiles https://t.co/H2kRsQ8anB',
#  '@RockSergeant @nytimes W H AA A A T?????? O M G! \U0001f92c\U0001f92c\U0001f92c\U0001f92c\U0001f92c\U0001f92c\U0001f92c\U0001f92c\U0001f92c\U0001f92c',
#  '@Huron_Nation @nytimes How many pedos in Rykers?',
#  '@RockSergeant @nytimes Wasn’t he going to release 300 from there? What an ignorant imbecile! Only hard core creeps get locked up on rykers! What is keeping someone, ANYONE from stopping this?!?! I’m livid!\U0001f92c\U0001f92c\U0001f92c no F ing accountability!',
#  '@Huron_Nation @nytimes Well since NY only lets rich people own guns, he knew what he was doing.',
#  "@nytimes Don't go to jail.",
#  '@nytimes Not good at all',
#  '@nytimes Are they still using prisoners as a bargain workforce?',
#  '@nytimes 😴😴😴',
#  "@nytimes Yeah, it's prison",
#  '@nytimes Another example of mismanagement by the current administration.',
#  '@nytimes Lock the doors and throw away the keys.',
#  '@donnynogood @nytimes POS like you should join them',
#  '@atheistlover13 @nytimes Soap dropper',
#  'There are similar fears at prisons across the U.S., which has more people behind bars than any other nation. Social distancing is impossible and sanitizer is widely banned. Even some prosecutors say inmates aren’t being released fast enough.\nhttps://t.co/firZDfnqRR',
#  '@nytimes Lock them down. Who cares they got free heathcare',
#  '@nytimes I honestly don’t known how to feel about this. Yes, they are humans, but do we really need to feel more #unsafe, with them out there, than we already do?',
#  '@nytimes All for release of inmates &amp; reforming our skewed criminal Justice system, BUT, where are they going upon release? Should be quarantined, NOT sent into society (often to homeless shelters) ad hoc, WITHOUT testing! Again, waited TOO late! Step BEHIND! Other states RU learning? NO!',
#  "@nytimes What? So this is not an hoax!? You the great president of the history! Can't solve this?\nThis is not and hoax from the fake news media!?\nCNN, MSNBC, NBC, CBS, ...even FOX are not lying?????????\nThis is not a big lie from the Left?\n https://t.co/izZ5cfVvKT",
#  '@nytimes So release them into to population so they can spread the virus to the general population.\n\nBrilliant absolutely effing brilliant.\n\nAll the while citizens are locked down...',
#  '@nytimes Yeah? Who woulda thought?',
#  '@nytimes Should of thought of that before you became a criminal',
#  "@bacarty2 @nytimes They still have rights, don't be such a jerk.",
#  '@atheistlover13 @nytimes They shouldnt have rights. Thats the problem with this country. We care for criminals more then our elders, more than a veterans shit more than the millions of kids who depend on schools to eat.',
#  '@bacarty2 @atheistlover13 @nytimes Cut the clown shit. https://t.co/J5Q7UrbKrE',
#  '@guasacaca05 @atheistlover13 @nytimes Which part. Fuck the criminals',
#  '@bacarty2 @nytimes Vote blue in Nov.',
#  '@atheistlover13 @nytimes Uhhhhh no lol. Ill keep my money thank you.',
#  "@nytimes That's what I feel like living in a condo."]
